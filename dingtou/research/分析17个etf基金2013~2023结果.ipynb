# %% [markdown]
# 测试我挑出来的行业和估值的17个etf的各自表现，
# 想看看有没有表现比较好的行业etf，
# 测试方案，就用[-0.4,0.8]+850，来测试，测试的话，就测试10年了，不在分不同年限了。

# %%
import pandas as pd
df = pd.read_csv("../debug/stat_17codes_20130101_20230101_10_3.csv")
df.columns
# Out:
# Index(['Unnamed: 0', '基金代码', '基准指数', '投资起始', '投资结束', '定投起始', '定投结束', '期初资金',
#        '期末现金', '期末持仓', '期末总值', '组合盈利', '组合收益', '组合年化', '基准收益', '基准年化', '基金收益',
#        '基金年化', '夏普比率', '索提诺比率', '卡玛比率', '最大回撤', '买次', '卖次', '成本', '持仓', '现价',
#        '佣金', '借钱总额', '借钱次数'],
#       dtype='object')

# %%
df1 = df[['基金代码', '期初资金','期末现金', '期末持仓', '期末总值', '组合盈利', '组合收益', '组合年化', '买次', '卖次',]]
df1.sort_values(by='组合年化',ascending=False)
# Out:
#       基金代码           期初资金          期末现金         期末持仓          期末总值  \
# 12  159915  544034.255986  1.128097e+06   53438.0616  1.181535e+06
# 13  159928   35001.852235  4.818749e+03   69519.6984  7.433845e+04
# 2   512580  363030.734143  7.581182e+05       0.0000  7.581182e+05
# 14  510330   43670.851203  1.883461e+04   64089.4852  8.292410e+04
# 1   512690   26000.841124  4.803794e+04       0.0000  4.803794e+04
# 9   512660  237020.421572  3.838151e+05   14897.8028  3.987129e+05
# 16  510500  388191.484406  6.410811e+05   11455.2900  6.525364e+05
# 11  512880  316024.946835  2.121383e+05  283160.3304  4.952986e+05
# 6   512980  227019.292759  4.168007e+04  298504.9358  3.401850e+05
# 15  512010  161966.817695  0.000000e+00  231662.2856  2.316623e+05
# 7   512800   88005.754996  1.784007e+04  105955.2600  1.237953e+05
# 5   516160  116134.707491  0.000000e+00  148773.2959  1.487733e+05
# 8   512200  347088.032390  0.000000e+00  395877.1028  3.958771e+05
# 10  510810  241299.531352  0.000000e+00  259537.3308  2.595373e+05
# 4   512760  106003.313671  0.000000e+00  108392.9640  1.083930e+05
# 0   515000  154011.807241  0.000000e+00  155014.9480  1.550149e+05
# 3   588090  342143.705998  0.000000e+00  324372.5200  3.243725e+05
#
#              组合盈利      组合收益      组合年化    买次    卖次
# 12  631675.437972  1.161095  0.080109  23.0   8.0
# 13   38980.890872  1.113681  0.077715  11.0   2.0
# 2   391241.527221  1.077709  0.075867  15.0   6.0
# 14   38634.883735  0.884684  0.065427  14.0   3.0
# 1    21793.100108  0.838169  0.062768   3.0   1.0
# 9   159678.509631  0.673691  0.052852  12.0   5.0
# 16  260962.443325  0.672252  0.052762  18.0  11.0
# 11  177417.461667  0.561403  0.045566  23.0   5.0
# 6   111457.403920  0.490960  0.040750  21.0   7.0
# 15   68956.397310  0.425744  0.036106  19.0   2.0
# 7    35117.090817  0.399032  0.034148  20.0   5.0
# 5    32263.717817  0.277813  0.024818  12.0   1.0
# 8    47714.189520  0.137470  0.012964  34.0   6.0
# 10   17594.930496  0.072917  0.007063  28.0   9.0
# 4     2379.051057  0.022443  0.002222   7.0   0.0
# 0      987.741118  0.006413  0.000639   6.0   0.0
# 3   -17881.689097 -0.052264 -0.005354  16.0   1.0

# %%
print(df.columns)

df[df['组合年化']>0.05]['基金代码'].tolist()
# Out:
# Index(['Unnamed: 0', '基金代码', '基准指数', '投资起始', '投资结束', '定投起始', '定投结束', '期初资金',
#        '期末现金', '期末持仓', '期末总值', '组合盈利', '组合收益', '组合年化', '基准收益', '基准年化', '基金收益',
#        '基金年化', '夏普比率', '索提诺比率', '卡玛比率', '最大回撤', '买次', '卖次', '成本', '持仓', '现价',
#        '佣金', '借钱总额', '借钱次数'],
#       dtype='object')
# [512690, 512580, 512660, 159915, 159928, 510330, 510500]
